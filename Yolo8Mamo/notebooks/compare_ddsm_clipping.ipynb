# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
filename1 = '/media/HD/mamo/DDSM_png/cancers/cancer_01/case0001/C_0001_1.LEFT_CC.png'
filename2 = '/media/HD/mamo/DDSM_png_noclipping/cases/cancers/cancer_01/case0001/C_0001_1.LEFT_CC.png'


img1 = np.array(Image.open(filename1))
img2 = np.array(Image.open(filename2))

# %%
print(img1.max())
print(img2.max())

im1f = img1.flatten()
im2f = img2.flatten()

# sample 4000 pixels
idx = np.random.choice(range(len(im1f)), 4000)
im1f = im1f[idx]
im2f = im2f[idx]

plt.figure()
plt.plot(im2f, im1f, '.')
# Out:
# 255
# 65535
